# %%
import cassandra
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json
import pandas as pd
import fiddler as fdl

# %%
cassandra.__version__
# Out:
# '3.28.0'

# %%
# This secure connect bundle is autogenerated when you donwload your SCB, 
# if yours is different update the file name below
cloud_config= {
  'secure_connect_bundle': 'datastax_auth/secure-connect-fiddlerai.zip'
}

# This token json file is autogenerated when you donwload your token, 
# if yours is different update the file name below
with open("datastax_auth/danny@fiddler.ai-token.json") as f:
    secrets = json.load(f)

CLIENT_ID = secrets["clientId"]
CLIENT_SECRET = secrets["secret"]

auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

# %%
session.set_keyspace('fiddlerai')

# %%
def pandas_factory(colnames, rows):
    return pd.DataFrame(rows, columns=colnames)

session.row_factory = pandas_factory
session.default_fetch_size = None

# %%
rows = session.execute('SELECT * FROM fiddler_doc_snippets_openai')
    
df_docs = rows._current_rows
df_docs
# Out:
#                                row_id attributes_blob  \
# 0    92623507537844779456935d731166a7            None
# 1    f37ba2e2aa5f47c4afe7ede8e9896e05            None
# 2    4c4d2927e9b9400d80596a0e71d7d5f0            None
# 3    70a6ea7c2cfa4fdb96ebb3beda022c24            None
# 4    19eaf41707e3460284184577ad55819d            None
# ..                                ...             ...
# 625  fd34d0931c374ebe9420b3869e1fc567            None
# 626  6caa8cf2fe60426a9e6d32fa88bbdd77            None
# 627  b4c745fbd1d1461bb937821e9fe663dc            None
# 628  3c34de11ae5a40c89e0889f105030519            None
# 629  6f2c1cdde1034d84b35e17f12f78dafe            None
#
#                                              body_blob   metadata_s  \
# 0    ---\ntitle: "Fairness"\nslug: "fairness"\nhidd...  [embedding]
# 1    ---\ntitle: "Useful Queries for Root Cause Ana...  [embedding]
# 2    slug: "clientpublish_events_batch" _S3",\n    ...  [embedding]
# 3    ---\ntitle: "Performance Tracking"\nslug: "per...  [embedding]
# 4    slug: "evaluation-ui" Calibration Plot_**\n  -...  [embedding]
# ..                                                 ...          ...
# 625  slug: "publishing-events-with-complex-data-for...  [embedding]
# 626  ---\ntitle: "fdl.AlertType"\nslug: "fdlalertty...  [embedding]
# 627  slug: "customer-churn-prediction" Churn-image5...  [embedding]
# 628  ---\ntitle: "client.build_notifications_config...  [embedding]
# 629  ---\ntitle: "Explainability"\nslug: "explainab...  [embedding]
#
#                                                 vector
# 0    [-0.022576844319701195, -0.009307874366641045,...
# 1    [0.008825183846056461, 0.027762411162257195, -...
# 2    [-0.02316180244088173, -0.011533494107425213, ...
# 3    [-0.013761984184384346, -0.005487993825227022,...
# 4    [-0.019045107066631317, -0.005970435217022896,...
# ..                                                 ...
# 625  [-0.009095759131014347, 0.018063507974147797, ...
# 626  [-0.0012485459446907043, 0.01317746564745903, ...
# 627  [0.0011718893656507134, 0.000443618802819401, ...
# 628  [-0.020654888823628426, 0.003742130473256111, ...
# 629  [0.010454350151121616, 0.01253423746675253, 0....
#
# [630 rows x 5 columns]

# %%
rows = session.execute('SELECT row_id, source_docs, response, question, comment, feedback, ts FROM fiddler_chatbot_history')
    
df = rows._current_rows
df
# Out:
#                                  row_id  \
# 0  cf69fb97-0805-46b0-b81d-77f36f484286
# 1  708cbabf-d065-4ff5-8fdf-d72a57edcaef
# 2  f57f810c-794a-484e-9895-c1ba16defe3f
# 3  f820dc8c-747a-4f00-a0fd-27bf4ca1d200
# 4  8c84be88-c7e6-42fd-83d2-aeefd731ae50
# 5  9cbbbb34-6336-4aed-a876-3704889b5814
# 6  02ae255e-0c16-4bdb-aed1-bedb4a47da46
# 7  e1009527-900e-4070-bb41-7931d47c5e26
# 8  fcc7318a-2b9d-4609-ade1-661d35761d70
#
#                                          source_docs  \
# 0    Document:  Fiddler provides a Python Client ...
# 1  Slack\n\nPagerDuty\n\n[block:html]\n{\n  "html...
# 2    Document:  Fiddler offers an integration wit...
# 3    Document:  [^1]\: Join our community Slack t...
# 4  Fiddler provides a Python Client that allows y...
# 5    Document:  In Fiddler, the default baseline ...
# 6    Document:  title: "Fiddler Docs Chat"\nslug:...
# 7    Document:  Zoom Slider  Document:  Zoom Slid...
# 8  Ranking is the task of constructing a rank ord...
#
#                                             response  \
# 0  You can find more information about the Python...
# 1  I could not find an answer.\nJoin our [Slack c...
# 2  Yes, I am a chatbot named Fiddler Chatbot. How...
# 3  Yes, you can ask me another question. How can ...
# 4  Yes, Fiddler provides a Python Client that all...
# 5  Yes, Fiddler supports multiple baselines. You ...
# 6  Yes, I am a chatbot called Fiddler Chatbot. I ...
# 7  I could not find an answer.\nJoin our [Slack c...
# 8  Ranking is the task of constructing a rank ord...
#
#                                             question           comment  \
# 0     Where do I learn more about the Python Client?              None
# 1                                      sadfasdfasdfs              None
# 2                                 Are you a chatbot?              None
# 3  Thanks for answering.  Can I ask you another q...              None
# 4                 Does Fiddler have a python client?      great answer
# 5           Does Fiddler support multiple baselines?  This was helpful
# 6                                 Are you a chatbot?              None
# 7                                    Does this work?              None
# 8                                            ranking             great
#
#    feedback                      ts
# 0       NaN 2023-10-11 20:08:24.502
# 1       NaN 2023-10-11 02:36:53.171
# 2       1.0 2023-10-11 21:16:36.707
# 3       NaN 2023-10-11 21:25:55.758
# 4       1.0 2023-10-11 02:40:42.068
# 5       0.0 2023-10-11 20:07:17.171
# 6       NaN 2023-10-11 21:13:28.105
# 7       NaN 2023-10-11 19:22:52.136
# 8      -1.0 2023-10-11 02:38:38.456

# %%
#session.execute("DELETE FROM fiddler_chatbot_conversation WHERE row_id='-1'")

# %%
#session.execute("DROP TABLE fiddler_chatbot_history")

# %%
session.execute("TRUNCATE TABLE fiddler_doc_snippets_openai")
